# %%
#import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create a set of random latitude and longitude combination
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add the latitudes and longtitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#     if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %%
#import the requests library
import requests

# import the API key
from config import weather_api_key

import time
from datetime import datetime

# %%
# starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an endpoint URL for a city
city_url = url +"&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 46.96,
#   'feels_like': 40.75,
#   'temp_min': 43.95,
#   'temp_max': 53.13,
#   'pressure': 1008,
#   'humidity': 69},
#  'visibility': 10000,
#  'wind': {'speed': 14.97, 'deg': 60},
#  'clouds': {'all': 100},
#  'dt': 1649016244,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1648981388,
#   'sunset': 1649027491},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# create an empty list to hold the weather data
city_data = []
# print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | nizwa
# Processing Record 2 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | poum
# Processing Record 4 of Set 1 | provideniya
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | beloha
# Processing Record 7 of Set 1 | bambous virieux
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | coihaique
# Processing Record 10 of Set 1 | airai
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | rudnogorsk
# Processing Record 17 of Set 1 | puerto suarez
# Processing Record 18 of Set 1 | fortuna
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | buraydah
# Processing Record 21 of Set 1 | sur
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | inuvik
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | chapais
# Processing Record 29 of Set 1 | todos santos
# Processing Record 30 of Set 1 | jacareacanga
# Processing Record 31 of Set 1 | coruripe
# Processing Record 32 of Set 1 | lazaro cardenas
# Processing Record 33 of Set 1 | ponta do sol
# Processing Record 34 of Set 1 | catuday
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 1 | la union
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | sampit
# Processing Record 40 of Set 1 | geraldton
# Processing Record 41 of Set 1 | bonavista
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | makakilo city
# Processing Record 44 of Set 1 | van
# Processing Record 45 of Set 1 | yumen
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | zigong
# Processing Record 1 of Set 2 | kimberley
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | kashi
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | fairview
# Processing Record 8 of Set 2 | constitucion
# Processing Record 9 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 2 | aswan
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | tambopata
# Processing Record 14 of Set 2 | morgan city
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | hami
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | beyneu
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | sioux lookout
# Processing Record 22 of Set 2 | ondo
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | lluta
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | sainte-rose
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 2 | merritt island
# Processing Record 32 of Set 2 | altay
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | marsaxlokk
# Processing Record 35 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 2 | olafsvik
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | sola
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | beringovskiy
# Processing Record 42 of Set 2 | oyem
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | iberia
# Processing Record 1 of Set 3 | eugene
# Processing Record 2 of Set 3 | rzhev
# Processing Record 3 of Set 3 | saint anthony
# Processing Record 4 of Set 3 | kamenka
# Processing Record 5 of Set 3 | kapoeta
# Processing Record 6 of Set 3 | kavaratti
# Processing Record 7 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 3 | biak
# Processing Record 9 of Set 3 | san quintin
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | ohara
# Processing Record 12 of Set 3 | vao
# Processing Record 13 of Set 3 | olga
# Processing Record 14 of Set 3 | douglas
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | phultala
# Processing Record 17 of Set 3 | kobelyaky
# Processing Record 18 of Set 3 | grandola
# Processing Record 19 of Set 3 | ambilobe
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | guarapari
# Processing Record 23 of Set 3 | port hardy
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | tateyama
# Processing Record 26 of Set 3 | tungor
# Processing Record 27 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 3 | zhigansk
# Processing Record 29 of Set 3 | mataura
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | katsuura
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | tiksi
# Processing Record 38 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 39 of Set 3 | callaguip
# Processing Record 40 of Set 3 | georgetown
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | tsiroanomandidy
# Processing Record 43 of Set 3 | crateus
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | namatanai
# Processing Record 46 of Set 3 | prince rupert
# Processing Record 47 of Set 3 | nam dinh
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | yulara
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | ndago
# Processing Record 2 of Set 4 | saint-paul
# Processing Record 3 of Set 4 | madang
# Processing Record 4 of Set 4 | son tay
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | ninohe
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 4 | dingle
# Processing Record 10 of Set 4 | okhotsk
# Processing Record 11 of Set 4 | the valley
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | bintulu
# Processing Record 14 of Set 4 | margate
# Processing Record 15 of Set 4 | menongue
# Processing Record 16 of Set 4 | port-gentil
# Processing Record 17 of Set 4 | qasigiannguit
# Processing Record 18 of Set 4 | la palma
# Processing Record 19 of Set 4 | padang
# Processing Record 20 of Set 4 | colares
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | montepuez
# Processing Record 23 of Set 4 | santiago del estero
# Processing Record 24 of Set 4 | keita
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | road town
# Processing Record 27 of Set 4 | bubaque
# Processing Record 28 of Set 4 | alofi
# Processing Record 29 of Set 4 | qurayyat
# Processing Record 30 of Set 4 | le mans
# Processing Record 31 of Set 4 | kupang
# Processing Record 32 of Set 4 | athabasca
# Processing Record 33 of Set 4 | north bend
# Processing Record 34 of Set 4 | kaihua
# Processing Record 35 of Set 4 | imeni poliny osipenko
# Processing Record 36 of Set 4 | eureka
# Processing Record 37 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 4 | tautira
# Processing Record 39 of Set 4 | albany
# Processing Record 40 of Set 4 | pousat
# City not found. Skipping...
# Processing Record 41 of Set 4 | redmond
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | ostrovnoy
# Processing Record 44 of Set 4 | port hedland
# Processing Record 45 of Set 4 | bermeo
# Processing Record 46 of Set 4 | deltona
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | san rafael
# Processing Record 49 of Set 4 | half moon bay
# Processing Record 50 of Set 4 | rio de jesus
# Processing Record 1 of Set 5 | hereford
# Processing Record 2 of Set 5 | mlonggo
# Processing Record 3 of Set 5 | caravelas
# Processing Record 4 of Set 5 | lasa
# Processing Record 5 of Set 5 | strezhevoy
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | baie-comeau
# Processing Record 8 of Set 5 | aras
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | san salvador
# Processing Record 11 of Set 5 | khorixas
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | isla vista
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | kieta
# Processing Record 16 of Set 5 | rincon
# Processing Record 17 of Set 5 | flinders
# Processing Record 18 of Set 5 | hvide sande
# Processing Record 19 of Set 5 | saint george
# Processing Record 20 of Set 5 | abu dhabi
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 5 | high level
# Processing Record 24 of Set 5 | simao
# Processing Record 25 of Set 5 | sandakan
# Processing Record 26 of Set 5 | barcelos
# Processing Record 27 of Set 5 | tahta
# Processing Record 28 of Set 5 | tonantins
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | vestmannaeyjar
# Processing Record 31 of Set 5 | moree
# Processing Record 32 of Set 5 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 33 of Set 5 | turtas
# Processing Record 34 of Set 5 | lakatoro
# Processing Record 35 of Set 5 | araguatins
# City not found. Skipping...
# Processing Record 36 of Set 5 | vardo
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | raga
# Processing Record 39 of Set 5 | tromso
# Processing Record 40 of Set 5 | vila franca do campo
# Processing Record 41 of Set 5 | turayf
# Processing Record 42 of Set 5 | comodoro rivadavia
# Processing Record 43 of Set 5 | garoua
# Processing Record 44 of Set 5 | villa bruzual
# Processing Record 45 of Set 5 | verkhoshizhemye
# Processing Record 46 of Set 5 | banihal
# Processing Record 47 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 5 | kurilsk
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 50 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 6 | dashitou
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | raudeberg
# Processing Record 5 of Set 6 | sakakah
# Processing Record 6 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 6 | pangnirtung
# Processing Record 8 of Set 6 | college
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | mount gambier
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | el sauzal
# Processing Record 13 of Set 6 | warri
# Processing Record 14 of Set 6 | nago
# Processing Record 15 of Set 6 | tatarsk
# Processing Record 16 of Set 6 | dzaoudzi
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | broome
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | fairbanks
# Processing Record 21 of Set 6 | gambela
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | panacan
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | meulaboh
# Processing Record 26 of Set 6 | brae
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | coquimbo
# Processing Record 29 of Set 6 | morondava
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | paris
# Processing Record 33 of Set 6 | vrangel
# Processing Record 34 of Set 6 | batemans bay
# Processing Record 35 of Set 6 | acarau
# Processing Record 36 of Set 6 | tomatlan
# Processing Record 37 of Set 6 | sao joao da barra
# Processing Record 38 of Set 6 | marawi
# Processing Record 39 of Set 6 | peniche
# Processing Record 40 of Set 6 | carbonear
# Processing Record 41 of Set 6 | pengcheng
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | quatre cocos
# Processing Record 44 of Set 6 | bogorodskoye
# Processing Record 45 of Set 6 | le port
# Processing Record 46 of Set 6 | hay river
# Processing Record 47 of Set 6 | port augusta
# Processing Record 48 of Set 6 | mount isa
# Processing Record 49 of Set 6 | praia
# Processing Record 50 of Set 6 | haines junction
# Processing Record 1 of Set 7 | hithadhoo
# Processing Record 2 of Set 7 | kataysk
# Processing Record 3 of Set 7 | holme
# Processing Record 4 of Set 7 | biltine
# Processing Record 5 of Set 7 | aranos
# Processing Record 6 of Set 7 | aykhal
# Processing Record 7 of Set 7 | najran
# Processing Record 8 of Set 7 | papara
# Processing Record 9 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 7 | mbamba
# Processing Record 11 of Set 7 | vanavara
# Processing Record 12 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 7 | khon kaen
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 7 | igarka
# Processing Record 17 of Set 7 | aklavik
# Processing Record 18 of Set 7 | bilma
# Processing Record 19 of Set 7 | daye
# Processing Record 20 of Set 7 | cidreira
# Processing Record 21 of Set 7 | yining
# Processing Record 22 of Set 7 | tallahassee
# Processing Record 23 of Set 7 | guadalupe victoria
# Processing Record 24 of Set 7 | aksarka
# Processing Record 25 of Set 7 | nortelandia
# Processing Record 26 of Set 7 | hasaki
# Processing Record 27 of Set 7 | osorno
# Processing Record 28 of Set 7 | kungurtug
# Processing Record 29 of Set 7 | cartagena
# Processing Record 30 of Set 7 | mayumba
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | canmore
# Processing Record 33 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | elat
# Processing Record 38 of Set 7 | zalesovo
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | zhucheng
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | dalbandin
# Processing Record 43 of Set 7 | porbandar
# Processing Record 44 of Set 7 | akhnur
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | saldanha
# Processing Record 48 of Set 7 | labuhan
# Processing Record 49 of Set 7 | bourail
# Processing Record 50 of Set 7 | virginia beach
# Processing Record 1 of Set 8 | mnogovershinnyy
# Processing Record 2 of Set 8 | aksarayskiy
# Processing Record 3 of Set 8 | georgiu-dezh
# City not found. Skipping...
# Processing Record 4 of Set 8 | puerto baquerizo moreno
# Processing Record 5 of Set 8 | lavrentiya
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | korla
# Processing Record 8 of Set 8 | esmeraldas
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | treinta y tres
# Processing Record 11 of Set 8 | gashua
# Processing Record 12 of Set 8 | paamiut
# Processing Record 13 of Set 8 | inhambane
# Processing Record 14 of Set 8 | sinnamary
# Processing Record 15 of Set 8 | el cobre
# Processing Record 16 of Set 8 | arinis
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | boa vista
# Processing Record 19 of Set 8 | pasni
# Processing Record 20 of Set 8 | itaituba
# Processing Record 21 of Set 8 | birjand
# Processing Record 22 of Set 8 | hays
# Processing Record 23 of Set 8 | pampa
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | la ronge
# Processing Record 26 of Set 8 | marion
# Processing Record 27 of Set 8 | iskateley
# Processing Record 28 of Set 8 | elko
# Processing Record 29 of Set 8 | nauta
# Processing Record 30 of Set 8 | christchurch
# Processing Record 31 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 8 | jizan
# Processing Record 33 of Set 8 | honningsvag
# Processing Record 34 of Set 8 | sheopur
# Processing Record 35 of Set 8 | umm kaddadah
# Processing Record 36 of Set 8 | rassvet
# Processing Record 37 of Set 8 | visby
# Processing Record 38 of Set 8 | dandong
# Processing Record 39 of Set 8 | los llanos de aridane
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | huambo
# Processing Record 42 of Set 8 | maragogi
# Processing Record 43 of Set 8 | umm lajj
# Processing Record 44 of Set 8 | fort saint james
# Processing Record 45 of Set 8 | nyaunglebin
# Processing Record 46 of Set 8 | mandali
# Processing Record 47 of Set 8 | balikpapan
# Processing Record 48 of Set 8 | finschhafen
# Processing Record 49 of Set 8 | asnaes
# Processing Record 50 of Set 8 | yarmouth
# Processing Record 1 of Set 9 | calamar
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | zaysan
# Processing Record 4 of Set 9 | del rio
# Processing Record 5 of Set 9 | husavik
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | golyshmanovo
# Processing Record 8 of Set 9 | seoul
# Processing Record 9 of Set 9 | corinth
# Processing Record 10 of Set 9 | kaitangata
# Processing Record 11 of Set 9 | adrar
# Processing Record 12 of Set 9 | keti bandar
# Processing Record 13 of Set 9 | araouane
# Processing Record 14 of Set 9 | muros
# Processing Record 15 of Set 9 | chumikan
# Processing Record 16 of Set 9 | cherskiy
# Processing Record 17 of Set 9 | flin flon
# Processing Record 18 of Set 9 | fare
# Processing Record 19 of Set 9 | verkhnyaya inta
# Processing Record 20 of Set 9 | sechura
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 9 | lekoni
# Processing Record 24 of Set 9 | laiagam
# City not found. Skipping...
# Processing Record 25 of Set 9 | sattahip
# Processing Record 26 of Set 9 | skibbereen
# Processing Record 27 of Set 9 | viana
# Processing Record 28 of Set 9 | gresham
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | chimore
# Processing Record 31 of Set 9 | barabai
# Processing Record 32 of Set 9 | hammerfest
# Processing Record 33 of Set 9 | chazuta
# Processing Record 34 of Set 9 | asfi
# Processing Record 35 of Set 9 | hamilton
# Processing Record 36 of Set 9 | huarmey
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | shingu
# Processing Record 39 of Set 9 | calama
# Processing Record 40 of Set 9 | gayeri
# Processing Record 41 of Set 9 | beira
# Processing Record 42 of Set 9 | camabatela
# Processing Record 43 of Set 9 | sompeta
# Processing Record 44 of Set 9 | bowen
# Processing Record 45 of Set 9 | san juan
# Processing Record 46 of Set 9 | mastic beach
# Processing Record 47 of Set 9 | kutum
# Processing Record 48 of Set 9 | codrington
# Processing Record 49 of Set 9 | kota bahru
# Processing Record 50 of Set 9 | klaksvik
# Processing Record 1 of Set 10 | washington
# Processing Record 2 of Set 10 | maningrida
# Processing Record 3 of Set 10 | coos bay
# Processing Record 4 of Set 10 | clinton
# Processing Record 5 of Set 10 | chapleau
# Processing Record 6 of Set 10 | evensk
# Processing Record 7 of Set 10 | livingston
# Processing Record 8 of Set 10 | valparaiso
# Processing Record 9 of Set 10 | samarai
# Processing Record 10 of Set 10 | riyadh
# Processing Record 11 of Set 10 | paracuru
# Processing Record 12 of Set 10 | bawku
# Processing Record 13 of Set 10 | kurchum
# Processing Record 14 of Set 10 | bad wildbad
# Processing Record 15 of Set 10 | shuangcheng
# Processing Record 16 of Set 10 | berlevag
# Processing Record 17 of Set 10 | pevek
# Processing Record 18 of Set 10 | maputo
# Processing Record 19 of Set 10 | san felipe
# Processing Record 20 of Set 10 | navabad
# City not found. Skipping...
# Processing Record 21 of Set 10 | wonthaggi
# Processing Record 22 of Set 10 | bouar
# Processing Record 23 of Set 10 | atyashevo
# Processing Record 24 of Set 10 | renala khurd
# Processing Record 25 of Set 10 | forrest city
# Processing Record 26 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 10 | evansville
# Processing Record 28 of Set 10 | tecoanapa
# Processing Record 29 of Set 10 | hovd
# Processing Record 30 of Set 10 | loudi
# Processing Record 31 of Set 10 | shar
# Processing Record 32 of Set 10 | north las vegas
# Processing Record 33 of Set 10 | mubende
# Processing Record 34 of Set 10 | dukat
# Processing Record 35 of Set 10 | kaduqli
# Processing Record 36 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 10 | mut
# Processing Record 38 of Set 10 | avera
# Processing Record 39 of Set 10 | otane
# Processing Record 40 of Set 10 | ucluelet
# Processing Record 41 of Set 10 | diapaga
# Processing Record 42 of Set 10 | naron
# Processing Record 43 of Set 10 | panzhihua
# Processing Record 44 of Set 10 | kondinskoye
# Processing Record 45 of Set 10 | santa fe
# Processing Record 46 of Set 10 | shieli
# Processing Record 47 of Set 10 | alenquer
# Processing Record 48 of Set 10 | santa maria
# Processing Record 49 of Set 10 | joshimath
# Processing Record 50 of Set 10 | luanda
# Processing Record 1 of Set 11 | dickinson
# Processing Record 2 of Set 11 | filingue
# Processing Record 3 of Set 11 | tual
# Processing Record 4 of Set 11 | klyuchi
# Processing Record 5 of Set 11 | milkovo
# Processing Record 6 of Set 11 | camana
# Processing Record 7 of Set 11 | fairlie
# Processing Record 8 of Set 11 | dumai
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | chibombo
# Processing Record 11 of Set 11 | souillac
# Processing Record 12 of Set 11 | guaimaro
# Processing Record 13 of Set 11 | tres arroyos
# Processing Record 14 of Set 11 | turukhansk
# Processing Record 15 of Set 11 | cap malheureux
# Processing Record 16 of Set 11 | ruteng
# Processing Record 17 of Set 11 | verkhnedneprovskiy
# Processing Record 18 of Set 11 | takoradi
# Processing Record 19 of Set 11 | corumba
# Processing Record 20 of Set 11 | kigoma
# Processing Record 21 of Set 11 | shambu
# Processing Record 22 of Set 11 | bourges
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 11 | golden
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | aguas formosas
# Processing Record 28 of Set 11 | cooma
# Processing Record 29 of Set 11 | lewistown
# Processing Record 30 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 11 | asekeyevo
# Processing Record 32 of Set 11 | rabo de peixe
# Processing Record 33 of Set 11 | jalu
# Processing Record 34 of Set 11 | isabela
# Processing Record 35 of Set 11 | bambanglipuro
# Processing Record 36 of Set 11 | veraval
# Processing Record 37 of Set 11 | tsabong
# Processing Record 38 of Set 11 | amurzet
# Processing Record 39 of Set 11 | lockhart
# Processing Record 40 of Set 11 | kalmunai
# Processing Record 41 of Set 11 | moron
# Processing Record 42 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 43 of Set 11 | sorland
# Processing Record 44 of Set 11 | marzuq
# Processing Record 45 of Set 11 | salalah
# Processing Record 46 of Set 11 | hambantota
# Processing Record 47 of Set 11 | asau
# Processing Record 48 of Set 11 | oga
# Processing Record 49 of Set 11 | gat
# Processing Record 50 of Set 11 | sarangani
# Processing Record 1 of Set 12 | samatau
# City not found. Skipping...
# Processing Record 2 of Set 12 | stephenville crossing
# Processing Record 3 of Set 12 | winslow
# Processing Record 4 of Set 12 | asuncion
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | maniitsoq
# Processing Record 7 of Set 12 | tigil
# Processing Record 8 of Set 12 | muzhi
# Processing Record 9 of Set 12 | irbil
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | rybinsk
# Processing Record 12 of Set 12 | gao
# Processing Record 13 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 12 | kokopo
# Processing Record 15 of Set 12 | loandjili
# Processing Record 16 of Set 12 | coracora
# Processing Record 17 of Set 12 | tay ninh
# Processing Record 18 of Set 12 | jiayuguan
# Processing Record 19 of Set 12 | metro
# Processing Record 20 of Set 12 | san isidro
# Processing Record 21 of Set 12 | escarcega
# Processing Record 22 of Set 12 | marand
# Processing Record 23 of Set 12 | xacmaz
# Processing Record 24 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 12 | soubre
# Processing Record 26 of Set 12 | portobelo
# Processing Record 27 of Set 12 | roald
# Processing Record 28 of Set 12 | daoukro
# Processing Record 29 of Set 12 | trabzon
# Processing Record 30 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 31 of Set 12 | bonthe
# Processing Record 32 of Set 12 | mocuba
# Processing Record 33 of Set 12 | pine bluff
# Processing Record 34 of Set 12 | port-cartier
# Processing Record 35 of Set 12 | ambon
# Processing Record 36 of Set 12 | nokaneng
# Processing Record 37 of Set 12 | moses lake
# Processing Record 38 of Set 12 | perevolotskiy
# Processing Record 39 of Set 12 | angra
# City not found. Skipping...
# Processing Record 40 of Set 12 | atherton
# Processing Record 41 of Set 12 | porto velho
# Processing Record 42 of Set 12 | kailua
# Processing Record 43 of Set 12 | ornskoldsvik
# Processing Record 44 of Set 12 | griffith
# Processing Record 45 of Set 12 | zhezkazgan
# Processing Record 46 of Set 12 | bathsheba
# Processing Record 47 of Set 12 | wadi musa
# Processing Record 48 of Set 12 | abong mbang
# Processing Record 49 of Set 12 | canon city
# Processing Record 50 of Set 12 | shelburne
# Processing Record 1 of Set 13 | neiafu
# Processing Record 2 of Set 13 | paragominas
# Processing Record 3 of Set 13 | bull savanna
# Processing Record 4 of Set 13 | namwala
# Processing Record 5 of Set 13 | parrita
# Processing Record 6 of Set 13 | armidale
# Processing Record 7 of Set 13 | pacific grove
# Processing Record 8 of Set 13 | independence
# Processing Record 9 of Set 13 | sakaiminato
# Processing Record 10 of Set 13 | tabuk
# Processing Record 11 of Set 13 | mokshan
# Processing Record 12 of Set 13 | cordoba
# Processing Record 13 of Set 13 | ternate
# Processing Record 14 of Set 13 | keetmanshoop
# Processing Record 15 of Set 13 | sitka
# Processing Record 16 of Set 13 | green river
# Processing Record 17 of Set 13 | moose factory
# Processing Record 18 of Set 13 | dakar
# Processing Record 19 of Set 13 | almaznyy
# Processing Record 20 of Set 13 | pochutla
# Processing Record 21 of Set 13 | knysna
# Processing Record 22 of Set 13 | rock sound
# Processing Record 23 of Set 13 | nioro
# Processing Record 24 of Set 13 | ayan
# Processing Record 25 of Set 13 | nemuro
# Processing Record 26 of Set 13 | havre-saint-pierre
# Processing Record 27 of Set 13 | ormara
# Processing Record 28 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 13 | kathu
# Processing Record 30 of Set 13 | eagle pass
# Processing Record 31 of Set 13 | mufumbwe
# Processing Record 32 of Set 13 | tochio
# Processing Record 33 of Set 13 | sept-iles
# Processing Record 34 of Set 13 | manta
# Processing Record 35 of Set 13 | sheridan
# Processing Record 36 of Set 13 | shenzhen
# Processing Record 37 of Set 13 | melilla
# Processing Record 38 of Set 13 | miri
# Processing Record 39 of Set 13 | lardos
# Processing Record 40 of Set 13 | nuevo progreso
# Processing Record 41 of Set 13 | huilong
# Processing Record 42 of Set 13 | chirongui
# Processing Record 43 of Set 13 | toul
# Processing Record 44 of Set 13 | nome
# Processing Record 45 of Set 13 | la romana
# Processing Record 46 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 13 | broken hill
# Processing Record 48 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 49 of Set 13 | havelock
# Processing Record 50 of Set 13 | antofagasta
# Processing Record 1 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | riachao do dantas
# Processing Record 3 of Set 14 | sigli
# Processing Record 4 of Set 14 | gamba
# Processing Record 5 of Set 14 | boden
# Processing Record 6 of Set 14 | linqiong
# Processing Record 7 of Set 14 | myslenice
# Processing Record 8 of Set 14 | malakal
# Processing Record 9 of Set 14 | leh
# Processing Record 10 of Set 14 | miraflores
# Processing Record 11 of Set 14 | manubul
# Processing Record 12 of Set 14 | sobolevo
# Processing Record 13 of Set 14 | graham
# Processing Record 14 of Set 14 | woodward
# Processing Record 15 of Set 14 | baykit
# Processing Record 16 of Set 14 | dongfeng
# Processing Record 17 of Set 14 | necochea
# Processing Record 18 of Set 14 | pula
# Processing Record 19 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 20 of Set 14 | thai binh
# Processing Record 21 of Set 14 | mbuji-mayi
# Processing Record 22 of Set 14 | motegi
# Processing Record 23 of Set 14 | aleksandrovskoye
# Processing Record 24 of Set 14 | merauke
# Processing Record 25 of Set 14 | progreso
# Processing Record 26 of Set 14 | northampton
# Processing Record 27 of Set 14 | xichang
# Processing Record 28 of Set 14 | wau
# Processing Record 29 of Set 14 | bugulma
# Processing Record 30 of Set 14 | xucheng
# Processing Record 31 of Set 14 | tongliao
# Processing Record 32 of Set 14 | pangody
# Processing Record 33 of Set 14 | vanimo
# Processing Record 34 of Set 14 | suntar
# Processing Record 35 of Set 14 | omboue
# Processing Record 36 of Set 14 | kawalu
# Processing Record 37 of Set 14 | watsa
# Processing Record 38 of Set 14 | caceres
# Processing Record 39 of Set 14 | port lincoln
# Processing Record 40 of Set 14 | trat
# Processing Record 41 of Set 14 | deputatskiy
# Processing Record 42 of Set 14 | tessalit
# Processing Record 43 of Set 14 | talavera de la reina
# Processing Record 44 of Set 14 | okha
# Processing Record 45 of Set 14 | quimper
# Processing Record 46 of Set 14 | belyy yar
# Processing Record 47 of Set 14 | okmulgee
# Processing Record 48 of Set 14 | koumac
# Processing Record 49 of Set 14 | lohardaga
# Processing Record 50 of Set 14 | sao luis do quitunde
# Processing Record 1 of Set 15 | aranda de duero
# Processing Record 2 of Set 15 | blackpool
# Processing Record 3 of Set 15 | iralaya
# Processing Record 4 of Set 15 | kapenguria
# Processing Record 5 of Set 15 | mahibadhoo
# Processing Record 6 of Set 15 | yambio
# Processing Record 7 of Set 15 | saryg-sep
# Processing Record 8 of Set 15 | kichera
# Processing Record 9 of Set 15 | vondrozo
# Processing Record 10 of Set 15 | ajaccio
# Processing Record 11 of Set 15 | emba
# Processing Record 12 of Set 15 | westport
# Processing Record 13 of Set 15 | luwuk
# Processing Record 14 of Set 15 | cam ranh
# Processing Record 15 of Set 15 | alvorada
# Processing Record 16 of Set 15 | severomuysk
# Processing Record 17 of Set 15 | nerchinskiy zavod
# Processing Record 18 of Set 15 | garowe
# Processing Record 19 of Set 15 | ketchikan
# Processing Record 20 of Set 15 | edd
# Processing Record 21 of Set 15 | valleyview
# Processing Record 22 of Set 15 | basoko
# Processing Record 23 of Set 15 | council bluffs
# Processing Record 24 of Set 15 | nuuk
# Processing Record 25 of Set 15 | henties bay
# Processing Record 26 of Set 15 | oulainen
# Processing Record 27 of Set 15 | manggar
# Processing Record 28 of Set 15 | toila
# Processing Record 29 of Set 15 | zeya
# Processing Record 30 of Set 15 | oksfjord
# Processing Record 31 of Set 15 | madisonville
# Processing Record 32 of Set 15 | pereslavl-zalesskiy
# Processing Record 33 of Set 15 | oktyabrskiy
# Processing Record 34 of Set 15 | port huron
# Processing Record 35 of Set 15 | bella union
# Processing Record 36 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 15 | mogzon
# Processing Record 38 of Set 15 | lalin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# convert the array of dictionaries to a Pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Nizwa  22.9333   57.5333     77.72        26           0
# 1             Poum -20.2333  164.0167     81.99        82         100
# 2      Provideniya  64.3833 -173.3000      2.80        74           0
# 3    Mar Del Plata -38.0023  -57.5575     75.22        64          40
# 4           Beloha -25.1667   45.0500     71.80        88           1
# 5  Bambous Virieux -20.3428   57.7575     80.22        83          75
# 6            Vaini -21.2000 -175.2000     73.56       100         100
# 7        Coihaique -45.5752  -72.0662     42.57        96         100
# 8            Airai  -8.9266  125.4092     56.95        77          20
# 9       Nikolskoye  59.7035   30.7861     29.71        96          35
#
#    Wind Speed Country                  Description
# 0        6.04      OM                    clear sky
# 1       17.81      NC                moderate rain
# 2       11.50      RU                    clear sky
# 3       21.85      AR             scattered clouds
# 4       10.36      MG                    clear sky
# 5       11.50      MU                broken clouds
# 6        5.75      TO  light intensity shower rain
# 7        8.25      CL                   light rain
# 8        1.16      TL                   few clouds
# 9        2.95      RU             scattered clouds

# %%
# create the output file(CSV)
output_data_file = "WeatherPy_Database.csv"
# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
